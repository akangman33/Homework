# %%
import random

# %%
p_girl = 0.49 + 0.51 * 0.49 + 0.51**2 * 0.49

def born_girl(n):
    count_girl = 0
    for j in range(1,n+1):
        for k in range(1,4):
            girl = 0
            i = random.randint(0,99)
            if i <= 48:
                print(str(j)+"："+"("+str(i)+")"+"女")
                girl = 1
                break
            elif k == "3":
                print(str(j)+"："+"("+str(i)+")"+"男")
                break
            else:
                print(str(j)+"："+"("+str(i)+")"+"男")
        if girl == 1:
            count_girl = count_girl+1
            girl = 0
    return "born_girl：" + str(count_girl/n)

print("p_girl：" + str(p_girl))
print(born_girl(10))
print(born_girl(10000))
# Out:
# p_girl：0.867349
# 1：(29)女
# 2：(51)男
# 2：(72)男
# 2：(58)男
# 3：(88)男
# 3：(22)女
# 4：(76)男
# 4：(14)女
# 5：(85)男
# 5：(1)女
# 6：(76)男
# 6：(58)男
# 6：(45)女
# 7：(34)女
# 8：(26)女
# 9：(40)女
# 10：(7)女
# born_girl：0.9
# 1：(22)女
# 2：(86)男
# 2：(84)男
# 2：(69)男
# 3：(45)女
# 4：(5)女
# 5：(78)男
# 5：(81)男
# 5：(42)女
# 6：(5)女
# 7：(91)男
# 7：(54)男
# 7：(49)男
# 8：(27)女
# 9：(46)女
# 10：(69)男
# 10：(57)男
# 10：(97)男
# 11：(26)女
# 12：(8)女
# 13：(89)男
# 13：(6)女
# 14：(85)男
# 14：(19)女
# 15：(85)男
# 15：(95)男
# 15：(38)女
# 16：(16)女
# 17：(40)女
# 18：(73)男
# 18：(17)女
# 19：(60)男
# 19：(79)男
# 19：(73)男
# 20：(66)男
# 20：(52)男
# 20：(25)女
# 21：(38)女
# 22：(50)男
# 22：(47)女
# 23：(99)男
# 23：(57)男
# 23：(89)男
# 24：(35)女
# 25：(27)女
# 26：(17)女
# 27：(23)女
# 28：(68)男
# 28：(65)男
# 28：(97)男
# 29：(34)女
# 30：(75)男
# 30：(53)男
# 30：(56)男
# 31：(67)男
# 31：(26)女
# 32：(7)女
# 33：(58)男
# 33：(21)女
# 34：(27)女
# 35：(51)男
# 35：(58)男
# 35：(44)女
# 36：(38)女
# 37：(39)女
# 38：(67)男
# 38：(13)女
# 39：(66)男
# 39：(73)男
# 39：(70)男
# 40：(64)男
# 40：(30)女
# 41：(23)女
# 42：(77)男
# ...
